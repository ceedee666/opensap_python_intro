# %% [markdown]
# # Questions for 1-7

# %% [markdown]
# What would be the output of the following code?
# - This could be your instruction!
# - This could be your instruction!
# 20
# - **20**
# - 5 + 15

# %%
a, b = 5, 15
if a < 5 and b > 10:
    print("This could be your instruction!")
elif a == 5 or b == 10:
    print(a + b)
